# %% [markdown]
# <a href="https://colab.research.google.com/github/Omer310341/Aurora-OS.js/blob/main/notebooks/ultimate_rvc_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Colab for [Ultimate RVC](https://github.com/JackismyShephard/ultimate-rvc)
#
# This Colab notebook will **help** you if you don’t have a GPU or if your PC isn’t very powerful.
#
# Simply click `Runtime` in the top navigation bar and `Run all`. Wait for the output of the final cell to show the public gradio url and click on it.
#
# NOTE: If Ultimate RVC is running too slowly with the default sharing method (gradio), consider instead selecting "ngrok" as sharing method.
# This method requires supplying an access token, which you can find on [ngrok](https://ngrok.com/) after creating a personal account.
# The ngrok link output in the final cell will lead you to a new site which will redirect you to Ultimate RVC.

# %%
# @title 0: Initialize notebook
# %pip install ipython-autotime pyngrok
# %load_ext autotime

import codecs
import os
import time
from pathlib import Path
from urllib import request

import ipywidgets as widgets
from IPython.display import clear_output
from IPython.display import display as i_display
from pyngrok import ngrok

clear_output()
# Out:
# time: 4.11 s (started: 2026-06-23 10:59:43 +00:00)

# %%
# @title 1: Clone repository
cloneing = codecs.decode(
    "uggcf://tvguho.pbz/WnpxvfzlFurcuneq/hygvzngr-eip.tvg",
    "rot_13",
)

# !git clone $cloneing HRVC
# %cd /content/HRVC
clear_output()
# Out:
# time: 2.72 s (started: 2026-06-23 10:59:47 +00:00)

# %%
# @title 2: Install dependencies

light = codecs.decode("uggcf://nfgeny.fu/hi/0.9.11/vafgnyy.fu", "rot_13")
inits = codecs.decode("./fep/hygvzngr_eip/pber/znva.cl", "rot_13")
prerelease = "--prerelease if-necessary-or-explicit"

# !apt install -y python3-dev unzip
# !curl -LsSf $light | sh

os.environ["URVC_CONSOLE_LOG_LEVEL"] = "WARNING"

# !uv run -q $prerelease $inits
# !uv add $prerelease matplotlib-inline==0.1.7
clear_output()
# Out:
# time: 4min 7s (started: 2026-06-23 10:59:50 +00:00)

# %%
# @title 3: Run Ultimate RVC
# @markdown  #### Choose a sharing method:

method = "ngrok"  # @param ["gradio",  "ngrok", "cloudflared","localtunnel"]
ngrok_token = "2vxfi72oRwkDM7I17OT1UaoEVwk_3wBdLUQmzG48zdk7UDpab"  # @param {type:"string"}
runpice = codecs.decode("./fep/hygvzngr_eip/jro/znva.cl", "rot_13")

if method == "gradio":
    # !uv run $prerelease $runpice --share
elif method == "ngrok":
    try:
        ngrok.set_auth_token(ngrok_token)
        ngrok.kill()
        tunnel = ngrok.connect(6969)
        print(f"Ngrok URL: {tunnel.public_url}")
        # !uv run $prerelease $runpice --listen-port 6969
    except Exception as e:  # noqa: BLE001
        print(f"Error starting ngrok: {e}")
elif method == "cloudflared":
    # !curl -LO https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
    # !dpkg -i cloudflared-linux-amd64.deb
    clear_output()
    # !rm -rf nohup.out
    # !nohup cloudflared tunnel --url localhost:6969 &
    clear_output()
    time.sleep(10)
    cloudflare_url = !grep -oE "https://[a-zA-Z0-9.-]+\.trycloudflare\.com" nohup.out
    print(f"URVC Public URL: {cloudflare_url}")
    # !uv run $prerelease $runpice --listen-port 6969
elif method == "localtunnel":
    # !npm install -g localtunnel &>/dev/null
    Path("url.txt").open("w", encoding="utf-8").close()
    # !lt --port 6969 >> url.txt 2>&1 &
    time.sleep(2)
    endpoint_ip = (
        request.urlopen("https://ipv4.icanhazip.com").read().decode("utf8").strip("\n")
    )
    tunnel_url = (
        Path("url.txt").read_text(encoding="utf-8").replace("your url is: ", "")
    )
    print(f"Share Link: {tunnel_url}")
    password_endpoint_widget = widgets.Text(
        value=endpoint_ip,
        description="Password IP:",
        disabled=True,
    )
    i_display(password_endpoint_widget)
    # !uv run $prerelease $runpice --listen-port 6969
# Out:
# Ngrok URL: https://2155-34-87-54-21.ngrok-free.app
# Bytecode compiled 19589 files in 2.18s
# * Running on local URL:  http://127.0.0.1:6969
# * To create a public link, set `share=True` in `launch()`.
# 100% 1/1 [00:21<00:00, 21.56s/it]
# [~] Extracting pitch features...
# 100% 44/44 [00:03<00:00, 13.66it/s]
# [~] Extracting audio embeddings...
# 100% 44/44 [00:01<00:00, 24.54it/s]
# /content/HRVC/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# /content/HRVC/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:430: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# Process Process-6:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/content/HRVC/src/ultimate_rvc/rvc/train/train.py", line 627, in run
#     train_and_evaluate(
#   File "/content/HRVC/src/ultimate_rvc/rvc/train/train.py", line 747, in train_and_evaluate
#     model_output = net_g(
#                    ^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1778, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1789, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/src/ultimate_rvc/rvc/lib/algorithm/synthesizers.py", line 199, in forward
#     o = self.dec(z_slice, pitchf, g=g)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1778, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1789, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/src/ultimate_rvc/rvc/lib/algorithm/generators/hifigan_nsf.py", line 224, in forward
#     resblock(x)
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1778, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1789, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/src/ultimate_rvc/rvc/lib/algorithm/residuals.py", line 85, in forward
#     x = conv2(x)
#         ^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1778, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1789, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/torch/nn/modules/conv.py", line 385, in forward
#     return self._conv_forward(input, self.weight, self.bias)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/torch/nn/modules/conv.py", line 380, in _conv_forward
#     return F.conv1d(
#            ^^^^^^^^^
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 100.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 37.75 MiB is free. Including non-PyTorch memory, this process has 14.52 GiB memory in use. Of the allocated memory 14.19 GiB is allocated by PyTorch, and 203.85 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)
# [rank0]:[W623 11:08:28.262187146 ProcessGroupNCCL.cpp:1647] Warning: WARNING: destroy_process_group() was not called before program exit, which can leak resources. For more info, please see https://pytorch.org/docs/stable/distributed.html#shutdown (function operator())
# 2026-06-23 11:08:29 - WARNING - ultimate_rvc.rvc.train.train - Process running on device 0 exited with code 1.
# Traceback (most recent call last):
#   File "/content/HRVC/src/ultimate_rvc/web/common.py", line 70, in _wrapped_fn
#     res = fn(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/src/ultimate_rvc/core/train/train.py", line 306, in run_training
#     train_main(
#   File "/content/HRVC/src/ultimate_rvc/rvc/train/train.py", line 274, in main
#     start()
#   File "/content/HRVC/src/ultimate_rvc/rvc/train/train.py", line 259, in start
#     raise RuntimeError(err_msg)
# RuntimeError: One or more training processes failed. See the logs or console for details.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/queueing.py", line 759, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/route_utils.py", line 354, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 2116, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 1623, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/anyio/to_thread.py", line 63, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 2592, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 1029, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/utils.py", line 915, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/src/ultimate_rvc/web/common.py", line 77, in _wrapped_fn
#     raise gr.Error(str(e)) from e
# gradio.exceptions.Error: 'One or more training processes failed. See the logs or console for details.'
# /content/HRVC/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# /content/HRVC/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:430: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# BurhanAI | epoch=1 | time=11:10:35 | training_speed=0:01:33 | best avg-gen-loss=5.784 (epoch 1)
# BurhanAI | epoch=2 | time=11:10:53 | training_speed=0:00:17 | best avg-gen-loss=5.032 (epoch 2)
# BurhanAI | epoch=3 | time=11:11:10 | training_speed=0:00:17 | best avg-gen-loss=4.838 (epoch 3)
# BurhanAI | epoch=4 | time=11:11:28 | training_speed=0:00:17 | best avg-gen-loss=4.341 (epoch 4)
# BurhanAI | epoch=5 | time=11:11:47 | training_speed=0:00:18 | best avg-gen-loss=4.341 (epoch 4)
# BurhanAI | epoch=6 | time=11:12:06 | training_speed=0:00:18 | best avg-gen-loss=4.285 (epoch 6)
# BurhanAI | epoch=7 | time=11:12:24 | training_speed=0:00:17 | best avg-gen-loss=4.234 (epoch 7)
# BurhanAI | epoch=8 | time=11:12:42 | training_speed=0:00:17 | best avg-gen-loss=4.095 (epoch 8)
# BurhanAI | epoch=9 | time=11:13:00 | training_speed=0:00:18 | best avg-gen-loss=4.065 (epoch 9)
# BurhanAI | epoch=10 | time=11:13:19 | training_speed=0:00:18 | best avg-gen-loss=4.055 (epoch 10)
# BurhanAI | epoch=11 | time=11:14:39 | training_speed=0:00:18 | best avg-gen-loss=4.055 (epoch 10)
# BurhanAI | epoch=12 | time=11:14:59 | training_speed=0:00:20 | best avg-gen-loss=4.055 (epoch 10)
# BurhanAI | epoch=13 | time=11:15:17 | training_speed=0:00:17 | best avg-gen-loss=4.031 (epoch 13)
# BurhanAI | epoch=14 | time=11:15:35 | training_speed=0:00:17 | best avg-gen-loss=4.006 (epoch 14)
# BurhanAI | epoch=15 | time=11:15:53 | training_speed=0:00:17 | best avg-gen-loss=4.006 (epoch 14)
# BurhanAI | epoch=16 | time=11:16:12 | training_speed=0:00:19 | best avg-gen-loss=3.994 (epoch 16)
# BurhanAI | epoch=17 | time=11:16:30 | training_speed=0:00:18 | best avg-gen-loss=3.990 (epoch 17)
# BurhanAI | epoch=18 | time=11:16:48 | training_speed=0:00:17 | best avg-gen-loss=3.980 (epoch 18)
# BurhanAI | epoch=19 | time=11:17:06 | training_speed=0:00:17 | best avg-gen-loss=3.961 (epoch 19)
# BurhanAI | epoch=20 | time=11:17:25 | training_speed=0:00:18 | best avg-gen-loss=3.890 (epoch 20)
# BurhanAI | epoch=21 | time=11:18:25 | training_speed=0:00:19 | best avg-gen-loss=3.877 (epoch 21)
# BurhanAI | epoch=22 | time=11:18:45 | training_speed=0:00:19 | best avg-gen-loss=3.877 (epoch 21)
# BurhanAI | epoch=23 | time=11:19:02 | training_speed=0:00:17 | best avg-gen-loss=3.870 (epoch 23)
# BurhanAI | epoch=24 | time=11:19:20 | training_speed=0:00:17 | best avg-gen-loss=3.840 (epoch 24)
# BurhanAI | epoch=25 | time=11:19:38 | training_speed=0:00:18 | best avg-gen-loss=3.840 (epoch 24)
# BurhanAI | epoch=26 | time=11:19:57 | training_speed=0:00:19 | best avg-gen-loss=3.803 (epoch 26)
# BurhanAI | epoch=27 | time=11:20:15 | training_speed=0:00:17 | best avg-gen-loss=3.803 (epoch 26)
# BurhanAI | epoch=28 | time=11:20:33 | training_speed=0:00:17 | best avg-gen-loss=3.803 (epoch 26)
# BurhanAI | epoch=29 | time=11:20:51 | training_speed=0:00:18 | best avg-gen-loss=3.803 (epoch 26)
# BurhanAI | epoch=30 | time=11:21:09 | training_speed=0:00:18 | best avg-gen-loss=3.803 (epoch 26)
# BurhanAI | epoch=31 | time=11:22:35 | training_speed=0:00:19 | best avg-gen-loss=3.803 (epoch 26)
# BurhanAI | epoch=32 | time=11:22:55 | training_speed=0:00:19 | best avg-gen-loss=3.803 (epoch 26)
# BurhanAI | epoch=33 | time=11:23:12 | training_speed=0:00:17 | best avg-gen-loss=3.803 (epoch 26)
# BurhanAI | epoch=34 | time=11:23:29 | training_speed=0:00:17 | best avg-gen-loss=3.752 (epoch 34)
# BurhanAI | epoch=35 | time=11:23:48 | training_speed=0:00:18 | best avg-gen-loss=3.752 (epoch 34)
# BurhanAI | epoch=36 | time=11:24:07 | training_speed=0:00:18 | best avg-gen-loss=3.752 (epoch 34)
# BurhanAI | epoch=37 | time=11:24:25 | training_speed=0:00:17 | best avg-gen-loss=3.752 (epoch 34)
# BurhanAI | epoch=38 | time=11:24:42 | training_speed=0:00:17 | best avg-gen-loss=3.752 (epoch 34)
# BurhanAI | epoch=39 | time=11:25:01 | training_speed=0:00:18 | best avg-gen-loss=3.752 (epoch 34)
# BurhanAI | epoch=40 | time=11:25:19 | training_speed=0:00:18 | best avg-gen-loss=3.752 (epoch 34)
# BurhanAI | epoch=41 | time=11:26:23 | training_speed=0:00:18 | best avg-gen-loss=3.752 (epoch 34)
# BurhanAI | epoch=42 | time=11:26:43 | training_speed=0:00:19 | best avg-gen-loss=3.752 (epoch 34)
# BurhanAI | epoch=43 | time=11:27:01 | training_speed=0:00:17 | best avg-gen-loss=3.752 (epoch 34)
# BurhanAI | epoch=44 | time=11:27:18 | training_speed=0:00:17 | best avg-gen-loss=3.752 (epoch 34)
# BurhanAI | epoch=45 | time=11:27:36 | training_speed=0:00:17 | best avg-gen-loss=3.752 (epoch 34)
# BurhanAI | epoch=46 | time=11:27:55 | training_speed=0:00:18 | best avg-gen-loss=3.752 (epoch 34)
# BurhanAI | epoch=47 | time=11:28:13 | training_speed=0:00:18 | best avg-gen-loss=3.752 (epoch 34)
# BurhanAI | epoch=48 | time=11:28:31 | training_speed=0:00:17 | best avg-gen-loss=3.752 (epoch 34)
# BurhanAI | epoch=49 | time=11:28:49 | training_speed=0:00:17 | best avg-gen-loss=3.752 (epoch 34)
# BurhanAI | epoch=50 | time=11:29:07 | training_speed=0:00:18 | best avg-gen-loss=3.752 (epoch 34)
# BurhanAI | epoch=51 | time=11:30:07 | training_speed=0:00:18 | best avg-gen-loss=3.752 (epoch 34)
# BurhanAI | epoch=52 | time=11:30:27 | training_speed=0:00:19 | best avg-gen-loss=3.752 (epoch 34)
# BurhanAI | epoch=53 | time=11:30:44 | training_speed=0:00:17 | best avg-gen-loss=3.752 (epoch 34)
# BurhanAI | epoch=54 | time=11:31:01 | training_speed=0:00:16 | best avg-gen-loss=3.752 (epoch 34)
# BurhanAI | epoch=55 | time=11:31:20 | training_speed=0:00:18 | best avg-gen-loss=3.738 (epoch 55)
# BurhanAI | epoch=56 | time=11:31:39 | training_speed=0:00:19 | best avg-gen-loss=3.738 (epoch 55)
# BurhanAI | epoch=57 | time=11:31:57 | training_speed=0:00:17 | best avg-gen-loss=3.738 (epoch 55)
# BurhanAI | epoch=58 | time=11:32:15 | training_speed=0:00:17 | best avg-gen-loss=3.738 (epoch 55)
# BurhanAI | epoch=59 | time=11:32:33 | training_speed=0:00:17 | best avg-gen-loss=3.738 (epoch 55)
# BurhanAI | epoch=60 | time=11:32:51 | training_speed=0:00:18 | best avg-gen-loss=3.738 (epoch 55)
# BurhanAI | epoch=61 | time=11:34:07 | training_speed=0:00:19 | best avg-gen-loss=3.713 (epoch 61)
# BurhanAI | epoch=62 | time=11:34:26 | training_speed=0:00:19 | best avg-gen-loss=3.713 (epoch 61)
# BurhanAI | epoch=63 | time=11:34:44 | training_speed=0:00:17 | best avg-gen-loss=3.713 (epoch 61)
# BurhanAI | epoch=64 | time=11:35:01 | training_speed=0:00:17 | best avg-gen-loss=3.713 (epoch 61)
# BurhanAI | epoch=65 | time=11:35:19 | training_speed=0:00:18 | best avg-gen-loss=3.713 (epoch 61)
# BurhanAI | epoch=66 | time=11:35:38 | training_speed=0:00:18 | best avg-gen-loss=3.713 (epoch 61)
# BurhanAI | epoch=67 | time=11:35:56 | training_speed=0:00:18 | best avg-gen-loss=3.713 (epoch 61)
# BurhanAI | epoch=68 | time=11:36:14 | training_speed=0:00:17 | best avg-gen-loss=3.713 (epoch 61)
# BurhanAI | epoch=69 | time=11:36:32 | training_speed=0:00:17 | best avg-gen-loss=3.713 (epoch 61)
# BurhanAI | epoch=70 | time=11:36:50 | training_speed=0:00:18 | best avg-gen-loss=3.713 (epoch 61)
# BurhanAI | epoch=71 | time=11:38:10 | training_speed=0:00:19 | best avg-gen-loss=3.713 (epoch 61)
# BurhanAI | epoch=72 | time=11:38:30 | training_speed=0:00:19 | best avg-gen-loss=3.713 (epoch 61)
# BurhanAI | epoch=73 | time=11:38:47 | training_speed=0:00:17 | best avg-gen-loss=3.713 (epoch 61)
# BurhanAI | epoch=74 | time=11:39:04 | training_speed=0:00:17 | best avg-gen-loss=3.713 (epoch 61)
# BurhanAI | epoch=75 | time=11:39:22 | training_speed=0:00:17 | best avg-gen-loss=3.713 (epoch 61)
# BurhanAI | epoch=76 | time=11:39:41 | training_speed=0:00:18 | best avg-gen-loss=3.713 (epoch 61)
# BurhanAI | epoch=77 | time=11:40:00 | training_speed=0:00:18 | best avg-gen-loss=3.713 (epoch 61)
# BurhanAI | epoch=78 | time=11:40:17 | training_speed=0:00:17 | best avg-gen-loss=3.713 (epoch 61)
# BurhanAI | epoch=79 | time=11:40:35 | training_speed=0:00:17 | best avg-gen-loss=3.713 (epoch 61)
# BurhanAI | epoch=80 | time=11:40:54 | training_speed=0:00:18 | best avg-gen-loss=3.713 (epoch 61)
# BurhanAI | epoch=81 | time=11:42:08 | training_speed=0:00:19 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=82 | time=11:42:28 | training_speed=0:00:19 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=83 | time=11:42:45 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=84 | time=11:43:02 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=85 | time=11:43:21 | training_speed=0:00:18 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=86 | time=11:43:40 | training_speed=0:00:19 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=87 | time=11:43:58 | training_speed=0:00:18 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=88 | time=11:44:16 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=89 | time=11:44:34 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=90 | time=11:44:52 | training_speed=0:00:18 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=91 | time=11:46:08 | training_speed=0:00:19 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=92 | time=11:46:27 | training_speed=0:00:19 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=93 | time=11:46:45 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=94 | time=11:47:02 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=95 | time=11:47:20 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=96 | time=11:47:39 | training_speed=0:00:19 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=97 | time=11:47:57 | training_speed=0:00:18 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=98 | time=11:48:15 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=99 | time=11:48:33 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=100 | time=11:48:52 | training_speed=0:00:18 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=101 | time=11:49:58 | training_speed=0:00:19 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=102 | time=11:50:17 | training_speed=0:00:19 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=103 | time=11:50:35 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=104 | time=11:50:52 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=105 | time=11:51:10 | training_speed=0:00:18 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=106 | time=11:51:29 | training_speed=0:00:19 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=107 | time=11:51:47 | training_speed=0:00:18 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=108 | time=11:52:05 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=109 | time=11:52:23 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=110 | time=11:52:41 | training_speed=0:00:18 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=111 | time=11:53:57 | training_speed=0:00:19 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=112 | time=11:54:16 | training_speed=0:00:19 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=113 | time=11:54:33 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=114 | time=11:54:51 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=115 | time=11:55:09 | training_speed=0:00:18 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=116 | time=11:55:28 | training_speed=0:00:18 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=117 | time=11:55:46 | training_speed=0:00:18 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=118 | time=11:56:04 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=119 | time=11:56:21 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=120 | time=11:56:40 | training_speed=0:00:18 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=121 | time=11:57:48 | training_speed=0:00:19 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=122 | time=11:58:08 | training_speed=0:00:19 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=123 | time=11:58:25 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=124 | time=11:58:43 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=125 | time=11:59:01 | training_speed=0:00:18 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=126 | time=11:59:20 | training_speed=0:00:18 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=127 | time=11:59:38 | training_speed=0:00:18 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=128 | time=11:59:56 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=129 | time=12:00:14 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=130 | time=12:00:32 | training_speed=0:00:18 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=131 | time=12:02:05 | training_speed=0:00:19 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=132 | time=12:02:24 | training_speed=0:00:19 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=133 | time=12:02:41 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=134 | time=12:02:58 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=135 | time=12:03:17 | training_speed=0:00:18 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=136 | time=12:03:36 | training_speed=0:00:18 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=137 | time=12:03:54 | training_speed=0:00:18 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=138 | time=12:04:12 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=139 | time=12:04:29 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=140 | time=12:04:48 | training_speed=0:00:18 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=141 | time=12:06:04 | training_speed=0:00:19 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=142 | time=12:06:24 | training_speed=0:00:19 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=143 | time=12:06:41 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=144 | time=12:06:58 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=145 | time=12:07:17 | training_speed=0:00:18 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=146 | time=12:07:36 | training_speed=0:00:19 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=147 | time=12:07:54 | training_speed=0:00:18 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=148 | time=12:08:12 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=149 | time=12:08:30 | training_speed=0:00:17 | best avg-gen-loss=3.704 (epoch 81)
# BurhanAI | epoch=150 | time=12:08:48 | training_speed=0:00:18 | best avg-gen-loss=3.704 (epoch 81)
# Training has been successfully completed with 150 epoch(s), 900 step(s) and 3.851 average generator loss.
# Lowest average generator loss: 3.704 at epoch 81
# [~] Retrieving song...
# [~] Separating vocals from instrumentals...
# 4.38kiB [00:00, 12.3MiB/s]
# 15.4kiB [00:00, 48.0MiB/s]
# 2026-06-23 12:50:55 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 4/4 [00:12<00:00,  3.06s/it]
# 100% 4/4 [00:01<00:00,  2.78it/s]
# [~] Separating main vocals from backup vocals...
# 2026-06-23 12:51:11 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 4/4 [00:08<00:00,  2.12s/it]
# 100% 4/4 [00:00<00:00,  5.11it/s]
# [~] De-reverbing vocals...
# 2026-06-23 12:51:22 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 7/7 [00:07<00:00,  1.13s/it]
# 100% 6/6 [00:00<00:00, 10.50it/s]
# [~] Converting vocals...
# [~] Post-processing vocals...
# [~] Pitch-shifting instrumentals...
# [~] Pitch-shifting backup vocals...
# [~] Retrieving song...
# [~] Separating vocals from instrumentals...
# 2026-06-23 12:53:49 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 49/49 [01:07<00:00,  1.37s/it]
# 100% 38/38 [00:09<00:00,  4.13it/s]
# [~] Separating main vocals from backup vocals...
# 2026-06-23 12:55:17 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 49/49 [00:47<00:00,  1.03it/s]
# 100% 38/38 [00:07<00:00,  4.87it/s]
# [~] De-reverbing vocals...
# 2026-06-23 12:56:22 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 97/97 [01:07<00:00,  1.44it/s]
# 100% 74/74 [00:09<00:00,  8.13it/s]
# [~] Converting vocals...
